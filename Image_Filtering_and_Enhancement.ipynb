# %% [markdown]
# <a href="https://colab.research.google.com/github/Reileen00/Basic-CV-projects/blob/main/Image_Filtering_and_Enhancement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import sys
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/1.webp')
if img is None:
    print("Error: Could not read the image. Please check the file path.")
    sys.exit()

# Apply Gaussian Blur
blurred_img = cv2.GaussianBlur(img, (15, 15), 0)

# Apply Edge Detection
edges = cv2.Canny(img, 100, 200)

# Display the images
cv2_imshow(img)
cv2_imshow(blurred_img)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=RGB size=640x280>
# <PIL.Image.Image image mode=RGB size=640x280>
# <PIL.Image.Image image mode=L size=640x280>
